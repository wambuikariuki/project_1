# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
#Install Libraries 
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#movie title 
movie_title = pd.read_csv(r"C:\Users\WAMBUI\Desktop\dsc-phase-1-project\zippedData\imdb.title.akas.csv.gz") 
movie_title
# Out:
#          title_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru    NaN
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención    NaN
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
# ...

# %%
#actors personal information
import pandas as pd 
personal_info = pd.read_csv(r"C:\Users\WAMBUI\Desktop\dsc-phase-1-project\zippedData\imdb.name.basics.csv.gz")
personal_info
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# ...

# %%
#movie basics 
movie_basics = pd.read_csv(r"C:\Users\WAMBUI\Desktop\dsc-phase-1-project\zippedData\imdb.name.basics.csv.gz") 

movie_basics
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# ...

# %%
#crew title

crew_info = pd.read_csv(r"C:\Users\WAMBUI\Desktop\dsc-phase-1-project\zippedData\imdb.title.crew.csv.gz") 

crew_info
# Out:
#            tconst                      directors              writers
# 0       tt0285252                      nm0899854            nm0899854
# 1       tt0438973                            NaN  nm0175726,nm1802864
# 2       tt0462036                      nm1940585            nm1940585
# 3       tt0835418                      nm0151540  nm0310087,nm0841532
# 4       tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
# ...           ...                            ...                  ...
# 146139  tt8999974                     nm10122357           nm10122357
# 146140  tt9001390                      nm6711477            nm6711477
# 146141  tt9001494          nm10123242,nm10123248                  NaN
# 146142  tt9004986                      nm4993825            nm4993825
# 146143  tt9010172                            NaN            nm8352242
#
# [146144 rows x 3 columns]

# %%
#movie identifiers
movie_id = pd.read_csv(r"C:\Users\WAMBUI\Desktop\dsc-phase-1-project\zippedData\imdb.title.principals.csv.gz") 
movie_id
# Out:
#             tconst  ordering      nconst  category       job  \
# 0        tt0111414         1   nm0246005     actor       NaN
# 1        tt0111414         2   nm0398271  director       NaN
# 2        tt0111414         3   nm3739909  producer  producer
# 3        tt0323808        10   nm0059247    editor       NaN
# 4        tt0323808         1   nm3579312   actress       NaN
# ...            ...       ...         ...       ...       ...
# 1028181  tt9692684         1   nm0186469     actor       NaN
# 1028182  tt9692684         2   nm4929530      self       NaN
# 1028183  tt9692684         3  nm10441594  director       NaN
# 1028184  tt9692684         4   nm6009913    writer    writer
# 1028185  tt9692684         5  nm10441595  producer  producer
#
#                    characters
# 0                 ["The Man"]
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4            ["Beth Boothby"]
# ...                       ...
# ...

# %%
#movie rating 
movie_ratings = pd.read_csv(r"C:\Users\WAMBUI\Desktop\dsc-phase-1-project\zippedData\imdb.title.ratings.csv.gz") 
                           
movie_ratings
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
#movie budget
movie_gross =pd.read_csv (r"C:\Users\WAMBUI\Desktop\dsc-phase-1-project\zippedData\tn.movie_budgets.csv.gz")
movie_gross
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
#movie income
movie_income = pd.read_csv(r"C:\Users\WAMBUI\Desktop\dsc-phase-1-project\zippedData\bom.movie_gross.csv.gz")
movie_income
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
import pandas as pd

# Assuming you have defined these dataframes: movie_id, movie_ratings, crew_info, movie_basics, movie_title, personal_info

# Merging the dataframes
movie_rating_id = pd.merge(movie_id, movie_ratings, on='tconst', how='outer') 
movie_rating_id_info = pd.merge(movie_rating_id, crew_info, on='tconst', how='outer') 
movie_rating_id_info_basics = pd.merge(movie_rating_id_info, movie_basics, on='nconst', how='outer') 
movie_rating_id_info_basics_title = pd.merge(movie_rating_id_info_basics, movie_title,
                                             left_on="nconst", right_on="title_id", how='outer')
movie_rating_id_info_basics_title_info = pd.merge(movie_rating_id_info_basics_title, personal_info, 
                                                  on="nconst", how='outer')

# Displaying the resulting dataframe
movie_rating_id_info_basics_title_info
# Out:
#             tconst  ordering_x     nconst  category       job   characters  \
# 0        tt0111414         1.0  nm0246005     actor       NaN  ["The Man"]
# 1        tt0111414         2.0  nm0398271  director       NaN          NaN
# 2        tt5573596         5.0  nm0398271  director       NaN          NaN
# 3        tt0111414         3.0  nm3739909  producer  producer          NaN
# 4        tt0323808        10.0  nm0059247    editor       NaN          NaN
# ...            ...         ...        ...       ...       ...          ...
# 1364932        NaN         NaN  nm9467868       NaN       NaN          NaN
# 1364933        NaN         NaN  nm9475692       NaN       NaN          NaN
# 1364934        NaN         NaN  nm9495701       NaN       NaN          NaN
# 1364935        NaN         NaN  nm9922562       NaN       NaN          NaN
# 1364936        NaN         NaN  nm9928666       NaN       NaN          NaN
#
# ...

# %%
movie_rating_id_info_basics_title_info.shape
# Out:
# (1364937, 28)

# %%
movie_rating_id_info_basics_title_info.isna().sum()
# Out:
# tconst                   334061
# ordering_x               336751
# nconst                   334393
# category                 336751
# job                     1187253
# characters               971577
# averagerating            735011
# numvotes                 735011
# directors                350350
# writers                  503897
# primary_name_x           334667
# birth_year_x            1130669
# death_year_x            1353034
# primary_profession_x     388340
# known_for_titles_x       365233
# title_id                1033234
# ordering_y              1033234
# title                   1033234
# region                  1086527
# language                1323222
# types                   1196490
# attributes              1350012
# is_original_title       1033259
# primary_name_y           334667
# birth_year_y            1130669
# death_year_y            1353034
# primary_profession_y     388340
# known_for_titles_y       365233
# dtype: int64

# %%
movie_rating_id_info_basics_title_info.isna().mean()
# Out:
# tconst                  0.244745
# ordering_x              0.246715
# nconst                  0.244988
# category                0.246715
# job                     0.869823
# characters              0.711811
# averagerating           0.538494
# numvotes                0.538494
# directors               0.256679
# writers                 0.369172
# primary_name_x          0.245189
# birth_year_x            0.828367
# death_year_x            0.991279
# primary_profession_x    0.284511
# known_for_titles_x      0.267582
# title_id                0.756983
# ordering_y              0.756983
# title                   0.756983
# region                  0.796027
# language                0.969438
# types                   0.876590
# attributes              0.989065
# is_original_title       0.757001
# primary_name_y          0.245189
# birth_year_y            0.828367
# death_year_y            0.991279
# primary_profession_y    0.284511
# known_for_titles_y      0.267582
# dtype: float64

# %%
#df.rename(columns={'old_column_name': 'new_column_name'}
movie_rating_id_info_basics_title_info.rename(columns={'nconst' : 'actor_id'})
movie_rating_id_info_basics_title_info.rename(columns={'tconst' : 'movie_id'})
# Out:
#           movie_id  ordering_x     nconst  category       job   characters  \
# 0        tt0111414         1.0  nm0246005     actor       NaN  ["The Man"]
# 1        tt0111414         2.0  nm0398271  director       NaN          NaN
# 2        tt5573596         5.0  nm0398271  director       NaN          NaN
# 3        tt0111414         3.0  nm3739909  producer  producer          NaN
# 4        tt0323808        10.0  nm0059247    editor       NaN          NaN
# ...            ...         ...        ...       ...       ...          ...
# 1364932        NaN         NaN  nm9467868       NaN       NaN          NaN
# 1364933        NaN         NaN  nm9475692       NaN       NaN          NaN
# 1364934        NaN         NaN  nm9495701       NaN       NaN          NaN
# 1364935        NaN         NaN  nm9922562       NaN       NaN          NaN
# 1364936        NaN         NaN  nm9928666       NaN       NaN          NaN
#
# ...

# %%
print(movie_rating_id_info_basics_title_info.columns)
# Out:
# Index(['tconst', 'ordering_x', 'nconst', 'category', 'job', 'characters',
#        'averagerating', 'numvotes', 'directors', 'writers', 'primary_name_x',
#        'birth_year_x', 'death_year_x', 'primary_profession_x',
#        'known_for_titles_x', 'title_id', 'ordering_y', 'title', 'region',
#        'language', 'types', 'attributes', 'is_original_title',
#        'primary_name_y', 'birth_year_y', 'death_year_y',
#        'primary_profession_y', 'known_for_titles_y'],
#       dtype='object')

# %%
project_1 = movie_rating_id_info_basics_title_info 
project_1
# Out:
#             tconst  ordering_x     nconst  category       job   characters  \
# 0        tt0111414         1.0  nm0246005     actor       NaN  ["The Man"]
# 1        tt0111414         2.0  nm0398271  director       NaN          NaN
# 2        tt5573596         5.0  nm0398271  director       NaN          NaN
# 3        tt0111414         3.0  nm3739909  producer  producer          NaN
# 4        tt0323808        10.0  nm0059247    editor       NaN          NaN
# ...            ...         ...        ...       ...       ...          ...
# 1364932        NaN         NaN  nm9467868       NaN       NaN          NaN
# 1364933        NaN         NaN  nm9475692       NaN       NaN          NaN
# 1364934        NaN         NaN  nm9495701       NaN       NaN          NaN
# 1364935        NaN         NaN  nm9922562       NaN       NaN          NaN
# 1364936        NaN         NaN  nm9928666       NaN       NaN          NaN
#
# ...

# %%
#dropping columns with high NAN values
#merged_df = merged_df.drop(columns= ['types', 'attributes', 'is_original_title', 'ordering'])
project_1 = project_1.drop(columns= ['job', 'birth_year_x',  'birth_year_y',  'death_year_x', 'death_year_x', 'characters', 'types', 'attributes',
                                     'is_original_title', 'ordering_y', 'language', 'region'])

# %%
print(project_1.columns)
# Out:
# Index(['tconst', 'ordering_x', 'nconst', 'category', 'averagerating',
#        'numvotes', 'directors', 'writers', 'primary_name_x',
#        'primary_profession_x', 'known_for_titles_x', 'title_id', 'title',
#        'primary_name_y', 'death_year_y', 'primary_profession_y',
#        'known_for_titles_y'],
#       dtype='object')

# %%
project_1 = project_1.drop(columns= ['ordering_x', 'primary_name_x',  'primary_profession_x',  'primary_profession_y', 'death_year_y', 'primary_name_y', 
                                     'known_for_titles_x', 'known_for_titles_y'])

# %%
project_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1364937 entries, 0 to 1364936
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1030876 non-null  object
#  1   nconst         1030544 non-null  object
#  2   category       1028186 non-null  object
#  3   averagerating  629926 non-null   float64
#  4   numvotes       629926 non-null   float64
#  5   directors      1014587 non-null  object
#  6   writers        861040 non-null   object
#  7   title_id       331703 non-null   object
#  8   title          331703 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 104.1+ MB

# %%
project_1 = project_1.drop(columns= ['writers'])

# %%
project_1
# Out:
#             tconst     nconst  category  averagerating  numvotes  directors  \
# 0        tt0111414  nm0246005     actor            NaN       NaN  nm0398271
# 1        tt0111414  nm0398271  director            NaN       NaN  nm0398271
# 2        tt5573596  nm0398271  director            7.8       6.0  nm0398271
# 3        tt0111414  nm3739909  producer            NaN       NaN  nm0398271
# 4        tt0323808  nm0059247    editor            3.9    2328.0  nm0362736
# ...            ...        ...       ...            ...       ...        ...
# 1364932        NaN  nm9467868       NaN            NaN       NaN        NaN
# 1364933        NaN  nm9475692       NaN            NaN       NaN        NaN
# 1364934        NaN  nm9495701       NaN            NaN       NaN        NaN
# 1364935        NaN  nm9922562       NaN            NaN       NaN        NaN
# 1364936        NaN  nm9928666       NaN            NaN       NaN        NaN
#
#         title_id title
# 0            NaN   NaN
# ...

# %%
project_1 = project_1.drop(columns= ['title_id'])

# %%
project_1
# Out:
#             tconst     nconst  category  averagerating  numvotes  directors  \
# 0        tt0111414  nm0246005     actor            NaN       NaN  nm0398271
# 1        tt0111414  nm0398271  director            NaN       NaN  nm0398271
# 2        tt5573596  nm0398271  director            7.8       6.0  nm0398271
# 3        tt0111414  nm3739909  producer            NaN       NaN  nm0398271
# 4        tt0323808  nm0059247    editor            3.9    2328.0  nm0362736
# ...            ...        ...       ...            ...       ...        ...
# 1364932        NaN  nm9467868       NaN            NaN       NaN        NaN
# 1364933        NaN  nm9475692       NaN            NaN       NaN        NaN
# 1364934        NaN  nm9495701       NaN            NaN       NaN        NaN
# 1364935        NaN  nm9922562       NaN            NaN       NaN        NaN
# 1364936        NaN  nm9928666       NaN            NaN       NaN        NaN
#
#         title
# 0         NaN
# 1         NaN
# ...

# %%
genre = pd.read_csv(r"C:\Users\WAMBUI\Desktop\dsc-phase-1-project\zippedData\rt.movie_info.tsv.gz", sep="\t", compression= "gzip")
genre
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
reviews = pd.read_csv(r"C:\Users\WAMBUI\Desktop\dsc-phase-1-project\zippedData\rt.reviews.tsv.gz", sep= "\t", compression= "gzip", encoding="latin1")
reviews
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
# ...

# %%
names = pd.read_csv(r"C:\Users\WAMBUI\Desktop\dsc-phase-1-project\zippedData\imdb.name.basics.csv.gz")
names
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# ...

# %%
titles = pd.read_csv(r"C:\Users\WAMBUI\Desktop\dsc-phase-1-project\zippedData\imdb.title.basics.csv.gz")
titles
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
project_1_titles = pd.merge(project_1, titles, on='tconst', how ="inner")
project_1_titles
# Out:
#             tconst     nconst  category  averagerating  numvotes  directors  \
# 0        tt0111414  nm0246005     actor            NaN       NaN  nm0398271
# 1        tt0111414  nm0398271  director            NaN       NaN  nm0398271
# 2        tt0111414  nm3739909  producer            NaN       NaN  nm0398271
# 3        tt5573596  nm0398271  director            7.8       6.0  nm0398271
# 4        tt5573596  nm0000476   actress            7.8       6.0  nm0398271
# ...            ...        ...       ...            ...       ...        ...
# 1030871  tt7659080        NaN       NaN            NaN       NaN  nm6474441
# 1030872  tt7763158        NaN       NaN            NaN       NaN        NaN
# 1030873  tt7980000        NaN       NaN            NaN       NaN        NaN
# 1030874  tt8352852        NaN       NaN            NaN       NaN        NaN
# 1030875  tt8835712        NaN       NaN            NaN       NaN        NaN
#
#         title                      primary_title  \
# ...

# %%
project_1_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1030876 entries, 0 to 1030875
# Data columns (total 12 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   tconst           1030876 non-null  object
#  1   nconst           1028186 non-null  object
#  2   category         1028186 non-null  object
#  3   averagerating    629926 non-null   float64
#  4   numvotes         629926 non-null   float64
#  5   directors        1014587 non-null  object
#  6   title            0 non-null        object
#  7   primary_title    1030876 non-null  object
#  8   original_title   1030855 non-null  object
#  9   start_year       1030876 non-null  int64
#  10  runtime_minutes  828893 non-null   float64
#  11  genres           1007380 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 102.2+ MB

# %%
project_1_titles.isna().sum()
# Out:
# tconst                   0
# nconst                2690
# category              2690
# averagerating       400950
# numvotes            400950
# directors            16289
# title              1030876
# primary_title            0
# original_title          21
# start_year               0
# runtime_minutes     201983
# genres               23496
# dtype: int64

# %%
project_1_titles.duplicated().sum()
# Out:
# 35

# %%
project_1 = project_1_titles.drop_duplicates()

# %%
project_1.duplicated().sum()
# Out:
# 0

# %%
project_1.isna().sum()
# Out:
# tconst                   0
# nconst                2690
# category              2690
# averagerating       400935
# numvotes            400935
# directors            16289
# title              1030841
# primary_title            0
# original_title          21
# start_year               0
# runtime_minutes     201967
# genres               23493
# dtype: int64

# %%
project_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1030841 entries, 0 to 1030875
# Data columns (total 12 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   tconst           1030841 non-null  object
#  1   nconst           1028151 non-null  object
#  2   category         1028151 non-null  object
#  3   averagerating    629906 non-null   float64
#  4   numvotes         629906 non-null   float64
#  5   directors        1014552 non-null  object
#  6   title            0 non-null        object
#  7   primary_title    1030841 non-null  object
#  8   original_title   1030820 non-null  object
#  9   start_year       1030841 non-null  int64
#  10  runtime_minutes  828874 non-null   float64
#  11  genres           1007348 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 102.2+ MB

# %%
project_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1030841 entries, 0 to 1030875
# Data columns (total 12 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   tconst           1030841 non-null  object
#  1   nconst           1028151 non-null  object
#  2   category         1028151 non-null  object
#  3   averagerating    629906 non-null   float64
#  4   numvotes         629906 non-null   float64
#  5   directors        1014552 non-null  object
#  6   title            0 non-null        object
#  7   primary_title    1030841 non-null  object
#  8   original_title   1030820 non-null  object
#  9   start_year       1030841 non-null  int64
#  10  runtime_minutes  828874 non-null   float64
#  11  genres           1007348 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 102.2+ MB

# %%
project_1_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1030876 entries, 0 to 1030875
# Data columns (total 12 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   tconst           1030876 non-null  object
#  1   nconst           1028186 non-null  object
#  2   category         1028186 non-null  object
#  3   averagerating    629926 non-null   float64
#  4   numvotes         629926 non-null   float64
#  5   directors        1014587 non-null  object
#  6   title            0 non-null        object
#  7   primary_title    1030876 non-null  object
#  8   original_title   1030855 non-null  object
#  9   start_year       1030876 non-null  int64
#  10  runtime_minutes  828893 non-null   float64
#  11  genres           1007380 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 102.2+ MB

# %%
project_1= project_1.dropna(subset=["primary_title"])

# %%
project_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1030841 entries, 0 to 1030875
# Data columns (total 12 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   tconst           1030841 non-null  object
#  1   nconst           1028151 non-null  object
#  2   category         1028151 non-null  object
#  3   averagerating    629906 non-null   float64
#  4   numvotes         629906 non-null   float64
#  5   directors        1014552 non-null  object
#  6   title            0 non-null        object
#  7   primary_title    1030841 non-null  object
#  8   original_title   1030820 non-null  object
#  9   start_year       1030841 non-null  int64
#  10  runtime_minutes  828874 non-null   float64
#  11  genres           1007348 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 102.2+ MB

# %%
project_1.isna().sum()
# Out:
# tconst                   0
# nconst                2690
# category              2690
# averagerating       400935
# numvotes            400935
# directors            16289
# title              1030841
# primary_title            0
# original_title          21
# start_year               0
# runtime_minutes     201967
# genres               23493
# dtype: int64

# %%
project_1.shape
# Out:
# (1030841, 12)

# %%
project_1= project_1.dropna(subset=["averagerating"])

# %%
project_1.isna().sum()
# Out:
# tconst                  0
# nconst                171
# category              171
# averagerating           0
# numvotes                0
# directors            3678
# title              629906
# primary_title           0
# original_title          0
# start_year              0
# runtime_minutes     62023
# genres               5225
# dtype: int64

# %%
project_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 629906 entries, 3 to 1028356
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           629906 non-null  object
#  1   nconst           629735 non-null  object
#  2   category         629735 non-null  object
#  3   averagerating    629906 non-null  float64
#  4   numvotes         629906 non-null  float64
#  5   directors        626228 non-null  object
#  6   title            0 non-null       object
#  7   primary_title    629906 non-null  object
#  8   original_title   629906 non-null  object
#  9   start_year       629906 non-null  int64
#  10  runtime_minutes  567883 non-null  float64
#  11  genres           624681 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 62.5+ MB

# %%
project_1.isna().sum()
# Out:
# tconst                  0
# nconst                171
# category              171
# averagerating           0
# numvotes                0
# directors            3678
# title              629906
# primary_title           0
# original_title          0
# start_year              0
# runtime_minutes     62023
# genres               5225
# dtype: int64

# %%
project_1= project_1.dropna(subset=["runtime_minutes"])

# %%
project_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 567883 entries, 10 to 1028354
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           567883 non-null  object
#  1   nconst           567790 non-null  object
#  2   category         567790 non-null  object
#  3   averagerating    567883 non-null  float64
#  4   numvotes         567883 non-null  float64
#  5   directors        565489 non-null  object
#  6   title            0 non-null       object
#  7   primary_title    567883 non-null  object
#  8   original_title   567883 non-null  object
#  9   start_year       567883 non-null  int64
#  10  runtime_minutes  567883 non-null  float64
#  11  genres           564440 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 56.3+ MB

# %%
project_1
# Out:
#              tconst     nconst category  averagerating  numvotes  directors  \
# 10        tt0323808  nm0059247   editor            3.9    2328.0  nm0362736
# 11        tt0323808  nm3579312  actress            3.9    2328.0  nm0362736
# 12        tt0323808  nm2694680    actor            3.9    2328.0  nm0362736
# 13        tt0323808  nm0574615    actor            3.9    2328.0  nm0362736
# 14        tt0323808  nm0502652  actress            3.9    2328.0  nm0362736
# ...             ...        ...      ...            ...       ...        ...
# 1028342   tt5690682        NaN      NaN            8.2       8.0        NaN
# 1028348   tt6449832        NaN      NaN            4.6      24.0        NaN
# 1028350   tt5514448        NaN      NaN            5.8       6.0        NaN
# 1028353   tt6449908        NaN      NaN            6.3      35.0        NaN
# 1028354  tt10112466        NaN      NaN            4.7      73.0        NaN
#
# ...

# %%
project_1= project_1.drop(columns=["title"])

# %%
project_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 567883 entries, 10 to 1028354
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           567883 non-null  object
#  1   nconst           567790 non-null  object
#  2   category         567790 non-null  object
#  3   averagerating    567883 non-null  float64
#  4   numvotes         567883 non-null  float64
#  5   directors        565489 non-null  object
#  6   primary_title    567883 non-null  object
#  7   original_title   567883 non-null  object
#  8   start_year       567883 non-null  int64
#  9   runtime_minutes  567883 non-null  float64
#  10  genres           564440 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 52.0+ MB

# %%
project_1
# Out:
#              tconst     nconst category  averagerating  numvotes  directors  \
# 10        tt0323808  nm0059247   editor            3.9    2328.0  nm0362736
# 11        tt0323808  nm3579312  actress            3.9    2328.0  nm0362736
# 12        tt0323808  nm2694680    actor            3.9    2328.0  nm0362736
# 13        tt0323808  nm0574615    actor            3.9    2328.0  nm0362736
# 14        tt0323808  nm0502652  actress            3.9    2328.0  nm0362736
# ...             ...        ...      ...            ...       ...        ...
# 1028342   tt5690682        NaN      NaN            8.2       8.0        NaN
# 1028348   tt6449832        NaN      NaN            4.6      24.0        NaN
# 1028350   tt5514448        NaN      NaN            5.8       6.0        NaN
# 1028353   tt6449908        NaN      NaN            6.3      35.0        NaN
# 1028354  tt10112466        NaN      NaN            4.7      73.0        NaN
#
# ...

# %%
# Create a histogram using seaborn to show distribution of IMDb ratings
plt.figure(figsize=(12, 8))
sns.histplot(project_1['averagerating'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of IMDb Ratings')
plt.xlabel('IMDb Rating')
plt.ylabel('Frequency')
plt.show()

# %%
#IMDb ratings vs number of votes
plt.figure(figsize=(12, 8))
sns.scatterplot(x='numvotes', y='averagerating', data=project_1, hue='category', alpha=0.7)
plt.title('Bivariate Analysis: IMDb Ratings vs Number of Votes')
plt.xlabel('Number of Votes')
plt.ylabel('IMDb Rating')
plt.legend(title='Category', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
#avarage rating by genre
project_1 = project_1.dropna(subset=['averagerating'])

# Split the 'genres' column into individual genres
project_1['genres'] = project_1['genres'].str.split(',')

# Create a new DataFrame to store exploded genres
project_1_genres = project_1.explode('genres')

# Bar plot for average rating by genre
plt.figure(figsize=(14, 8))
sns.barplot(x='genres', y='averagerating', data=project_1_genres, ci=None)
plt.title('Average IMDb Ratings by Genre')
plt.xlabel('Genre')
plt.ylabel('Average Rating')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-140e0658246a> in <module>
#      10 # Bar plot for average rating by genre
#      11 plt.figure(figsize=(14, 8))
# ---> 12 sns.barplot(x='genres', y='averagerating', data=project_1_genres, ci=None)
#      13 plt.title('Average IMDb Ratings by Genre')
#      14 plt.xlabel('Genre')
#
# c:\Users\WAMBUI\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
#percentage occurence
#count occurence of each genre
genre_counts = pd.Series({'Action': 30, 'Comedy': 20, 'Drama': 25, 'Thriller': 15, 'Horror': 10})

# Define explode list with the same length as genre_counts
explode = [0.1] * len(genre_counts)

# Define colors
colors = plt.cm.Set3.colors  # Use Set3 color map for better visibility

# Plot the pie chart
plt.pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%', startangle=90, colors=colors, explode=explode)

# Draw a circle in the center of the pie to make it look like a donut chart
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Scatter plot: averagerating vs. numvotes
plt.figure(figsize=(10, 6))
sns.scatterplot(x='numvotes', y='averagerating', data=project_1, alpha=0.5)
plt.title('Scatter Plot: Average Rating vs. Number of Votes')
plt.xlabel('Number of Votes')
plt.ylabel('Average Rating')
plt.show()

# %%
# Scatter plot: averagerating vs. runtime_minutes
plt.figure(figsize=(10, 6))
sns.scatterplot(x='runtime_minutes', y='averagerating', data=project_1, alpha=0.5)
plt.title('Scatter Plot: Average Rating vs. Runtime Minutes')
plt.xlabel('Runtime Minutes')
plt.ylabel('Average Rating')
plt.show()

# %%
# Scatter plot: numvotes vs. runtime_minutes
plt.figure(figsize=(10, 6))
sns.scatterplot(x='runtime_minutes', y='numvotes', data=project_1, alpha=0.5)
plt.title('Scatter Plot: Number of Votes vs. Runtime Minutes')
plt.xlabel('Runtime Minutes')
plt.ylabel('Number of Votes')
plt.show()

# %%
The graph above suggests that movies or shows with longer runtimes tend to attract less votes, hence horter content may be more favorable for audience engagement, leading to a higher number of votes
